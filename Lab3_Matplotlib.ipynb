# %% [markdown]
# <a href="https://colab.research.google.com/github/TheSpaceMan915/Artificial-Intelligence/blob/main/Lab3_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Лабораторная работа №3  Колычев Никита  ВПР34**

# %% [markdown]
# # **№1 Легенда**

# %% [markdown]
# # **1. Измените положение легенды в Matplotlib**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# creating data
arr_data1 = np.linspace(1,50,50)
np.random.seed(1)
arr_data2 = np.random.randint(0,20,50)

# creating an empty canvas
fig = plt.figure()

# creating x,y axes (a 2d drawing area)
axes = fig.add_axes([0.1,0.1,0.8,0.8])

# creating a graph with a legend for the axis
axes.plot(arr_data1, arr_data2, "coral", label="Legend")

# putting the legend in the right bottom corner
axes.legend(loc=4)

# %% [markdown]
# # **2. Как изменить размер шрифта легенды в Matplotlib?**

# %%
# creating data
arr_data1 = np.linspace(1,50,50)
np.random.seed(1)
arr_data2 = np.random.randint(0,100,50)

# creating an empty canvas
fig = plt.figure()

# creating x,y axes (a 2d drawing area)
axes = fig.add_axes([0.1,0.1,0.8,0.8])

# creating a graph with a legend for the axis
axes.plot(arr_data1, arr_data2, "magenta", label="Legend")

# changing the font and its size
plt.rcParams.update({"font.size": 16, "font.family": "serif"})

# showing the legend
axes.legend()

# %% [markdown]
# # **3. Как изменить расстояние по вертикали между записями легенды в Matplotlib?**

# %%
# creating data
x = np.linspace(1,50,50)
y1 = np.random.randint(0,30,50)
y2 = np.random.randint(0,30,50)

# creating an empty canvas
fig = plt.figure()

# creating x,y axes (a 2d drawing area)
axes = fig.add_axes([0.1,0.1,0.8,0.8])

# creating two axes with a legend
axes.plot(x, y1, "b", label="y1")
axes.plot(x, y2, "g", label="y2")

# changing spacing between legend entries
axes.legend(labelspacing = 1)

# %% [markdown]
# # **4. Используйте несколько столбцов в легенде Matplotlib**

# %%
# creating data
x = np.linspace(1,20,10)
y1 = x**2
y2 = np.random.randint(0,30,10)

# creating an empty canvas
fig = plt.figure()

# creating x,y axes (a 2d drawing area)
axes = fig.add_axes([0.1,0.1,0.8,0.8])

# creating two axes with a legend
axes.plot(x, y1, color = tuple(np.random.rand(3)), label="y1",)
axes.plot(x, y2, color = tuple(np.random.rand(3)), label="y2")

# changing the number of columns in the legend
axes.legend(ncol = 2)

# %% [markdown]
# # **5. Как создать единую легенду для всех подзаголовков в Matplotlib?**

# %%
# creating data
x1 = np.linspace(1,20,10)
x2 = np.linspace(1,20,10)
y1 = x1**2
y2 = x2**3

#  creating 2 subplots in 1 row and 2 colums
fig, (ax1, ax2) = plt.subplots(1, 2)

# creating two axes with the same legend
ax1.plot(x1, y1, "g", label="y1")
ax2.plot(x2, y2, "c", label="y2")

# putting the legend in the upper right corner
fig.legend(loc="upper right")

# adjusting the graphs so they don't cross
fig.tight_layout()

# %% [markdown]
# # **6. Как вручную добавить легенду с цветной рамкой на фигуру Matplotlib?**

# %%
# creating data
x = np.linspace(1,20,10)
y1 = x**2
y2 = np.random.randint(0,30,10)

# creating an empty canvas
fig = plt.figure()

# creating x,y axes (a 2d drawing area)
axes = fig.add_axes([0.1,0.1,0.8,0.8])

# creating two axes with a legend
axes.plot(x, y1, "b", label="y1")
axes.plot(x, y2, "g", label="y2")

# getting a legend object from the axes
leg = axes.legend()

# changing the colour of the edge
leg.get_frame().set_edgecolor("orange")

# %% [markdown]
# # **7. Как разместить легенду за пределами сюжета в Matplotlib?**

# %%
# creating data
x = np.linspace(1,5,10)
y1 = x**2
y2 = np.random.randint(0,10,10)

# creating an empty canvas
fig = plt.figure()

# creating x,y axes (a 2d drawing area)
axes = fig.add_axes([0.1,0.1,0.8,0.8])

# creating two axes with a legend
axes.plot(x, y1, "b", label="y1")
axes.plot(x, y2, "g", label="y2")

# shrinking the axes by 20%
box = axes.get_position()
axes.set_position([box.x0, box.y0, box.width * 0.8, box.height])

#  putting the legend to the right of the axes
axes.legend(loc="best", bbox_to_anchor=(1, 0., 0.5, 0.5))

# %% [markdown]
# # **8. Удалите границу легенды в Matplotlib**

# %%
# creating data
arr_data1 = np.linspace(1,50,50)
np.random.seed(1)
arr_data2 = np.random.randint(0,20,50)

# creating an empty canvas
fig = plt.figure()

# creating x,y axes (a 2d drawing area)
axes = fig.add_axes([0.1,0.1,0.8,0.8])

# creating a graph with a legend for the axis
axes.plot(arr_data1, arr_data2, color = tuple(np.random.rand(3)), label="Legend")

# shrinking the axes by 20%
box = axes.get_position()
axes.set_position([box.x0, box.y0, box.width * 0.8, box.height])

#  putting the legend to the right of the axes
leg = axes.legend(loc="center left", bbox_to_anchor=(1, 0., 0.5, 0.5))

# removing the border of the legend
leg.get_frame().set_linewidth(0.0)

# %% [markdown]
# # **№2 Линейная диаграмма**

# %% [markdown]
# # **1. Постройте горизонтальную линию в Matplotlib (использовать plt.axhline)**

# %%
plt.axhline(y = 0.3, color = "magenta", linestyle = "-")

# %% [markdown]
# # **2. Постройте несколько горизонтальных линий разных типов, ширины и цветов на одном графике**

# %%
# creating data
x = np.linspace(1,20,30)

# creating an empty canvas and axes
fig, ax = plt.subplots(figsize=(12,6))

# creating a few lines
ax.plot(x, x + 1, color = tuple(np.random.rand(3)), linewidth = "1", linestyle = "--", marker = "o", markersize = 3)
ax.plot(x, x + 2, color = tuple(np.random.rand(3)), linewidth = "2", linestyle = "-.", marker = "o", markersize = 4, markerfacecolor = "black")
ax.plot(x, x - 1, color = tuple(np.random.rand(3)), linewidth = "2", linestyle = (5, (10, 3)), marker = "s", markersize = 2, markeredgewidth = 4)

# %% [markdown]
# # **3. Постройте вертикальную линию в Matplotlib**

# %%
plt.axvline(x = 2, color = "green")

# %% [markdown]
# # **4. Постройте несколько вертикальных линий разных типов, ширины и цветов на одном графике**

# %%
plt.axvline(x = 2, color = "red", linewidth = "2", linestyle = ":", marker = "o", markersize = 4)
plt.axvline(x = 3, color = "black", linewidth = "4", linestyle = "-", marker = "+", markersize = 3, markerfacecolor = "red")
plt.axvline(x = 3.25, color = "magenta", linewidth = "1", linestyle = "--", marker = "*", markersize = 4, markeredgewidth = 3)

# %% [markdown]
# # **5. Измените непрозрачность строки в Matplotlib**

# %%
# creating data
x = np.linspace(1,50,30)

# changing the transparency of the line using alpha attribute
plt.plot(x, x + 1, color = "black", linestyle = "--", alpha = 0.25)

# %% [markdown]
# # **6. Увеличьте толщину линии с помощью Matplotlib**

# %%
# increasing the width of the line using linewidth attribute
plt.axvline(x = 3, color = "orange", linewidth = 2)

# %% [markdown]
# # **7. Как заполнить между несколькими строками в Matplotlib?**

# %%
# creating data
x = np.linspace(1,10,20)
y1 = x**2
y2 = x**3

# creating an empty canvas and axes
fig, axes = plt.subplots()

# plotting the graph
axes.fill_between(x, y1, y2, color = "orange", alpha = 0.45)

# %% [markdown]
# # **№3 Гистограмма**

# %% [markdown]
# # **1. Нарисуйте горизонтальную гистограмму с помощью Matplotlib**

# %%
# creating data
x = np.random.randn(100)

# creating an empty canvas and axes
fig, axes = plt.subplots()

# creating a histogram
axes.hist(x)
axes.set_xlim((min(x), max(x)))
axes.set_title("Histogram")
# Out:
# Text(0.5, 1.0, 'Histogram')

# %% [markdown]
# # **2. Как отобразить значение каждого столбца на гистограмме с помощью Matplotlib?**

# %%
# creating data
x = np.random.randn(1000)

# creating an empty canvas and axes
fig, axes = plt.subplots(1, figsize = (10,6))

# creating a histogram
counts, edges, bars = plt.hist(x)
axes.set_xlim((min(x), max(x)))
axes.set_title("Histogram")

# creating x ticks
xticks = [(edges[index+1] + value)/2 for index, value in enumerate(edges[:-1])]

# showing values on the bars
for index, value in enumerate(counts): 
  plt.text(xticks[index], value, int(value), horizontalalignment="center")

# %% [markdown]
# # **3. Как аннотировать столбцы в Barplot с помощью Matplotlib на Python?**

# %%
# creating data
x = np.array([i for i in range(10)])

# creating an empty canvas and axes
fig, axes = plt.subplots(1, figsize = (10,12))

# creating a bar graph
axes.bar(x, x + 2, align = "center", width = 0.5, alpha = 0.4)
axes.set_title("Bar")

# creating patches
arr_rectangles = axes.patches

# creating a few labels
arr_labels = [f"Label{i}" for i in range(len(x))]

# putting the labels on the bars
for rect, label in zip(arr_rectangles, arr_labels):
  height = rect.get_height()
  axes.text(rect.get_x() + rect.get_width() / 2, height + 0.2, label, ha = "center", va = "bottom")

# %% [markdown]
# # **4. Как аннотировать столбцы в сгруппированном столбчатом графике на Python?**

# %%
# creating data
arr_number_cats = [1,3,1,2,2]
arr_number_dogs = [2,3,2,1,1]

# initialising the locations of the labels and the width between the bars
x = np.arange(len(arr_number_cats))
width = 0.3

# creating an empty canvas and axes
fig, axes = plt.subplots(1, figsize = (10,12))

# changing the font and its size
plt.rcParams.update({"font.size": 16, "font.family": "serif"})

# creating a bar graph
rectangles1 = axes.bar(x-width/2, arr_number_cats, width, label = "Cats")
rectangles2 = axes.bar(x+width/2, arr_number_dogs, width, label = "Dogs")

# adding titles and labels
axes.set_ylabel("Number of animals", fontsize = "medium")
axes.set_title("Family pets")
axes.legend()

# adding bar labels
for rect, label in zip(rectangles1, arr_number_cats):
  height = rect.get_height()
  axes.text(rect.get_x() + rect.get_width() / 2, height + 0.05, label, ha = "center", va = "bottom")

for rect, label in zip(rectangles2, arr_number_dogs):
  height = rect.get_height()
  axes.text(rect.get_x() + rect.get_width() / 2, height + 0.05, label, ha = "center", va = "bottom")

# %% [markdown]
# # **5. Изобразите столбчатую диаграмму колонки «Класс жилья». Расположите в порядке убывания размеры столбцов**

# %%
# reading a csv file from the drive
path_file = "/content/drive/MyDrive/Colab Notebooks/AI/Datasets/flat_offers.csv"
data_frame = pd.read_csv(path_file)

# creating an empty canvas and axes
fig, axes = plt.subplots(figsize = (10,12))

type_counts = data_frame["Класс жилья"].value_counts()
axes.bar(type_counts.index, type_counts.values)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # **№4 Точечная диаграмма**

# %% [markdown]
# # **1. Как добавить легенду к точечной диаграмме в Matplotlib?**

# %%
# creating data
x = np.random.randn(500)
y = np.random.rand(500)

# creating an empty canvas and axes
fig, axes = plt.subplots()

# creating a scatter graph
axes.scatter(x, y, label = "Person")
axes.set_title("Scatter graph")

# showing the legend
axes.legend(loc=4)

# %% [markdown]
# # **2. Как соединить точки диаграммы рассеяния с линией в Matplotlib?**

# %%
# creating data
x = np.linspace(1, 10, num = 10)
y = np.random.rand(10)

# creating an empty canvas and axes
fig, axes = plt.subplots()

# creating a scatter graph
axes.scatter(x, y)
axes.set_title("Scatter graph")

# connecting the points
axes.plot(x,y)

# %% [markdown]
# # **3. Как создать точечную диаграмму с несколькими цветами в Matplotlib?**

# %%
# creating data
x = np.linspace(1, 10, num = 10)
y1 = np.random.rand(10)
y2 = np.random.rand(10)

# creating an empty canvas and axes
fig, axes = plt.subplots()

# creating a scatter graph using color attribute
axes.scatter(x, y1, color = "orange")
axes.scatter(x, y2, color = "green")
axes.set_title("Scatter graph")

# connecting the points
axes.plot(x, y1, color = "orange")
axes.plot(x, y2, color = "green")

# %% [markdown]
# # **4. Как увеличить размер точек разброса в Matplotlib?**

# %%
# creating data
x = np.linspace(1, 10, num = 10)
y1 = np.random.rand(10)

# creating an empty canvas and axes
fig, axes = plt.subplots()

# creating a scatter graph using size attribute
axes.scatter(x, y1, color = "purple", s = 100)

# connecting the points
axes.plot(x, y1, color = "purple")

# %% [markdown]
# # **№5 Круговая диаграмма**

# %% [markdown]
# # **1. Постройте круговую диаграмму в Python, используя Matplotlib**

# %%
# creating labels
arr_genres = ["Education", "Comics", "History", "Fantasy"]

# creating sizes
arr_sizes = [25, 10, 10, 55]
tuple_explodes = (0.1, 0, 0, 0)

# creating an empty canvas and axes
fig, axes = plt.subplots(1, figsize = (6,8))

# changing the font and its size
plt.rcParams.update({"font.size": 18, "font.family": "STIXGeneral", "mathtext.fontset": "stix"})

# creating a pie chart
axes.pie(arr_sizes, explode = tuple_explodes, labels = arr_genres, autopct = "%1.1f%%" ,shadow = True)
axes.set_title("Pie chart")
axes.axis("equal")
# Out:
# (-1.114096586272883, 1.1747491192801567, -1.1143510444926343, 1.17476123633824)

# %% [markdown]
# # **2. Как установить границу для клиньев в круговой диаграмме Matplotlib?**

# %%
# creating labels
arr_genres = ["Education", "Comics", "History", "Fantasy"]

# creating sizes
arr_sizes = [25, 10, 10, 55]
tuple_explodes = (0.1, 0, 0, 0)

# creating an empty canvas and axes
fig, axes = plt.subplots(1, figsize = (6,8))

# changing the font and its size
plt.rcParams.update({"font.size": 18, "font.family": "STIXGeneral", "mathtext.fontset": "stix"})

# creating a pie chart and setting up the borders using wedgeprops attribute
axes.pie(arr_sizes, explode = tuple_explodes, labels = arr_genres, autopct = "%1.1f%%" ,shadow = True, startangle = 90, 
         wedgeprops = {"linestyle": "-", "linewidth": 3, "edgecolor": "black"})
axes.set_title("Pie chart")
axes.axis("equal")
# Out:
# (-1.17476123633824,
#  1.1143510444926343,
#  -1.1140965862728833,
#  1.1747491192801567)

# %% [markdown]
# # **3. Радиально сместите клин круговой диаграммы в Matplotlib**

# %%
# creating labels
arr_genres = ["Education", "Comics", "History", "Fantasy"]

# creating sizes
arr_sizes = [25, 10, 10, 55]
tuple_explodes = (0.1, 0, 0, 0)

# creating an empty canvas and axes
fig, axes = plt.subplots(1, figsize = (6,8))

# changing the font and its size
plt.rcParams.update({"font.size": 18, "font.family": "STIXGeneral", "mathtext.fontset": "stix"})

# creating a pie chart and changing the angle of the chart using startangle attribute
axes.pie(arr_sizes, explode = tuple_explodes, labels = arr_genres, autopct = "%1.1f%%" ,shadow = True, startangle = 90)
axes.set_title("Pie chart")
axes.axis("equal")
# Out:
# (-1.17476123633824,
#  1.1143510444926343,
#  -1.1140965862728833,
#  1.1747491192801567)

# %% [markdown]
# # **№5 Общие настройки графиков**

# %% [markdown]
# # **1. Как изменить прозрачность графика в Matplotlib с помощью Python?**

# %%
# creating data
x1 = np.linspace(1,20,10)
y1 = np.random.randint(1,100,10)

#  creating an empty canvas and axes
fig, axes = plt.subplots(1, figsize = (7, 7))

# changing the transparency using the alpha attribute
axes.plot(x1, y1, "g", alpha = 0.2)

# %% [markdown]
# # **2. Как изменить цвет графика в Matplotlib с помощью Python?**

# %%
# creating data
x1 = np.linspace(1,20,10)
y1 = np.random.randint(1,100,10)

#  creating an empty canvas and axes
fig, axes = plt.subplots(1, figsize = (7, 7))

# setting up the colour of the graph using the color attribute
axes.plot(x1, y1, color = "orange")

# %% [markdown]
# # **3. Как изменить размер шрифта заголовка на рисунке Matplotlib?**

# %%
# creating data
x1 = np.linspace(1,20,10)
y1 = np.random.randint(1,100,10)

#  creating an empty canvas and axes
fig, axes = plt.subplots(1, figsize = (7, 7))

# changing the size of the graph title using the fontsize attribute
axes.plot(x1, y1, color = "orange")
axes.set_title("Chart", fontdict = {"fontsize": 24})
# Out:
# Text(0.5, 1.0, 'Chart')

# %% [markdown]
# # **4. Как установить размер шрифта для меток в Matplotlib?**

# %%
# creating data
x1 = np.linspace(0,100, num = 11)
y1 = np.random.randint(0,100,11)

#  creating an empty canvas and axes
fig, axes = plt.subplots(1, figsize = (7, 7))

# creating a graph
axes.plot(x1, y1, color = "coral")
arr_labels = ["", r"$\alpha$", r"$\beta$", r"2$\beta$", r"$\gamma$", r"$\delta$", r"$\epsilon$",]

# changing the size of the xticks
axes.set_xticklabels(arr_labels, fontsize = 18)
# Out:
# <ipython-input-274-389eee17bcee>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes.set_xticklabels(arr_labels, fontsize = 18)
# [Text(-20.0, 0, ''),
#  Text(0.0, 0, '$\\alpha$'),
#  Text(20.0, 0, '$\\beta$'),
#  Text(40.0, 0, '2$\\beta$'),
#  Text(60.0, 0, '$\\gamma$'),
#  Text(80.0, 0, '$\\delta$'),
#  Text(100.0, 0, '$\\epsilon$'),
#  Text(120.0, 0, '')]

# %% [markdown]
# # **5. Как задать цвет фона графика в Matplotlib?**

# %%
# creating data
x1 = np.linspace(1,20,10)
y1 = np.random.randint(1,100,10)

#  creating an empty canvas and axes
fig, axes = plt.subplots(1, figsize = (7, 7))

# creating a graph
axes.plot(x1, y1, color = "coral")
axes.set_title("Chart")

# changing the background colour
axes.set_facecolor("black")

# %% [markdown]
# # **6. Как сгенерировать случайный цвет для графика Matplotlib в Python?**

# %%
# creating data
x1 = np.linspace(0,100, num = 11)
y1 = np.random.randint(0,100,11)

#  creating an empty canvas and axes
fig, axes = plt.subplots(1, figsize = (7, 7))

# creating a graph with a random colour by generating a tuple of 3 random integers
axes.plot(x1, y1, color = tuple(np.random.rand(3)))

# %% [markdown]
# # **7. Добавьте текст внутри графика в Matplotlib / 8. Как добавить текст в Matplotlib?**

# %%
# creating data
x1 = np.linspace(0,100, num = 11)
y1 = np.random.randint(0,100,11)

#  creating an empty canvas and axes
fig, axes = plt.subplots(1, figsize = (7, 7))

# creating a graph
axes.plot(x1, y1, color = tuple(np.random.rand(3)))

# adding some text to the graph
axes.text(20, 20, "Some text", ha = "center", va = "bottom")
# Out:
# Text(20, 20, 'Some text')

# %% [markdown]
# # **9. Как изменить размер цветовой панели Matplotlib в Python?**

# %%
# creating data
arr_data = np.random.randint(0, 100, size = (2,3))

#  creating an empty canvas and axes
fig, axes = plt.subplots(1, figsize = (7, 7))

# showing the data as an image
img = plt.imshow(arr_data)

# changing the size of the colorbar using the shrink() method
plt.colorbar(shrink = 0.4)

# %% [markdown]
# # **10. Как изменить размер фигур, нарисованных с помощью matplotlib?**

# %%
# creating data
x1 = np.linspace(0,100, num = 10)
y1 = np.random.randint(0,100,10)

#  creating an empty canvas and axes. Using the figsize attribute to change the size of the figure
fig, axes = plt.subplots(1, figsize = (8, 10))

# creating a graph
axes.plot(x1, y1, color = "purple")

# %% [markdown]
# # **11. Как вручную добавить легенду с цветной рамкой на фигуру Matplotlib?**

# %%
# creating data
x = np.linspace(0,20,10)
y1 = x + 2
y2 = np.random.randint(0,30,10)

#  creating an empty canvas and axes. 
fig, axes = plt.subplots(1, figsize = (6, 8))

# creating two axes with a legend
axes.plot(x, y1, color = tuple(np.random.rand(3)), label="y1")
axes.plot(x, y2, color = tuple(np.random.rand(3)), label="y2")

# getting a legend object from the axes
leg = axes.legend()

# changing the colour of the edge
leg.get_frame().set_edgecolor("black")

# %% [markdown]
# # **12. Как изменить размер меток осей в Matplotlib?**

# %%
# creating data
x = np.linspace(0,20,10)
y1 = x + 2
y2 = np.random.randint(0,30,10)

#  creating an empty canvas and axes. 
fig, axes = plt.subplots(1, figsize = (6, 8))

# creating two axes with a legend
axes.plot(x, y1, color = tuple(np.random.rand(3)), label="y1")
axes.plot(x, y2, color = tuple(np.random.rand(3)), label="y2")

# getting a legend object from the axes
leg = axes.legend()

# changing the size of xticks and yticks
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # **13. Как скрыть метки текста оси или метки в Matplotlib?**

# %%
# creating data
x = np.linspace(0,20,10)
y1 = x + 2
y2 = np.random.randint(0,30,10)

#  creating an empty canvas and axes. 
fig, axes = plt.subplots(1, figsize = (6, 8))

# creating two axes with a legend
axes.plot(x, y1, color = tuple(np.random.rand(3)), label="y1")
axes.plot(x, y2, color = tuple(np.random.rand(3)), label="y2")

# getting a legend object from the axes
leg = axes.legend()

# removing xticks and yticks and their labels
axes.tick_params(left = False, bottom = False, labelleft = False, labelbottom = False)

# %% [markdown]
# # **14. Как настроить положение меток осей в Matplotlib?**

# %%
# creating data
x = np.linspace(0,20,10)
y1 = x + 2
y2 = np.random.randint(0,30,10)

# creating ticks
arr_xticks = np.linspace(0, 20, num = 10)
arr_yticks = np.linspace(0, 25, num = 15)

#  creating an empty canvas and axes. 
fig, axes = plt.subplots(1, figsize = (6, 8))

# creating two axes with a legend
axes.plot(x, y1, color = tuple(np.random.rand(3)), label="y1")
axes.plot(x, y2, color = tuple(np.random.rand(3)), label="y2")
axes.set_title("Graph")

# getting a legend object from the axes
leg = axes.legend()

# setting up the ticks on the fixed positions
axes.set_xticks(arr_xticks)
axes.set_yticks(arr_yticks)

# %% [markdown]
# # **15. Скрыть ось, границы и пробелы в Matplotlib**

# %%
# creating data
x = np.linspace(0,20,10)
y1 = np.random.rand(10)
y2 = np.random.rand(10)

# creating ticks
arr_xticks = np.linspace(0, 20, num = 10)
arr_yticks = np.linspace(0, 25, num = 15)

#  creating an empty canvas and axes. 
fig, axes = plt.subplots(1, figsize = (6, 8))

# creating two axes with a legend
axes.plot(x, y1, color = tuple(np.random.rand(3)), label="y1")
axes.plot(x, y2, color = tuple(np.random.rand(3)), label="y2")

# hiding the axes
plt.axis("off")
# Out:
# (-1.0, 21.0, 0.04419728144982705, 0.9787899446359725)
